# %% [raw]
# (1) In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [raw]
#  * = multiplication expressions
# 'hello' = string
# -87.8 = float
# - = substraction expressions
# / = division expression
# + = addition expression
# 6 = integer

# %% [raw]
# (2) What is the difference between string and variable?

# %% [raw]
# variable  =  variable is the set of data(information) in the form of integer, string or some other data type.
#             example:-
#                        test = "sweet"
#                        num = 5
#                      as per above example the test and num are the variable which conatins the information in the form of string and interger.
#
# string  =  string is a sequence of characteras and alphbets. and string is surrounded by the double quotation or the single quotation.
#            example:
#                     "hello word"
#                     as per given example the the string is made of alphabets cahracters.
#                     it immutable and

# %% [raw]
# (3)Describe three different data types.

# %% [raw]
# the three data types are as below
#
#  (1) numeric type
#  (2) sequence type
#  (3) mapping type
#
#  (1) numeric data type:
#                       there is three data type in the numeric data type:
#                       (1) int
#                       (2) float
#                       (3) complex
#
#                       (1) int: the whole number value which don't have any any decimal point or any complex character with                                 positive and negative unlimited size is called as int data type
#                           exmple: x = 50
#
#
#                       (2) float: the number with positive and negetive value which have the decimal point is called as the float                                  data type
#                                  ex: x = 50.1
#
#                       (3) complex: a number which is written with imaginary number like j is called as complex data type.
#                                    ex: x = 5+6j
#
#  (2) sequence data type:  there is three data type in the sequence data type:
#                       (1) list
#                       (2) tuple
#                       (3) range
#
#                       (1) list: in list the data can store between the square bracket like [] and store the multiple multiple                             items in single variables. list is ordered, changeble and allow duplicate value.
#
#                           ex.: name = ["raj","jay","ram"]
#
#                       (2) tuple: in tuple the data can store between the round bracket like () and tuples also can store                                   multiple items in the single variable. tuples are ordered, unchangeble and allow duplicate.
#
#                           ex.: name = ("raj","jay","ram")
#
#                        (3) set: in set the data can store between the curly bracket like {} and it can also store multiple items                            in single variable. set are unordered, unchangeble and duplicates not allowed.
#
#                            ex.: name = {"raj","jay","ram"}
#
#  (3) mapping data type: dict is only data type is the mapping, in dict the data can store the key:values pairs. dict are ordered     and changeble and do not allow duplicate.
#     ex.:  identity = { "name":"rahul" , "surname":"maurya","mail":"rahul@gmail.com"}

# %% [raw]
# (4)  What is an expression made up of? What do all expressions do?

# %% [raw]
# the combination of operators and operands that is interpreted to produce the final output is called as the expression.
#
# the expression are as below:
#                        (1) arithmetic expression : combination of numerical values and operators and the result of arithmetic                                operation is in numeric value.
#                            the operators in arithmetic operation used like addition(+), substraction (-), multiplication(*),                                division (/)
#                        (2) integral expression : the expression which only produce the integer value after all type conversion
#                            is called as the integral expression.
#                        (3) floating expression: the expression which produce the floating number after all type conversion is
#                            called as the floating expression.

# %% [raw]
# (5) This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [raw]
# expression always evaluates to a value by the matheatical operation. and the statement is like variable which only dsplay the value. in the given question in spam = 10 the spam is statement which shows the values only.

# %% [raw]
# (6) After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %% [raw]
# the variable bacon caontain 23

# %% [raw]
# (7) What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %%
'spam' + 'spamspam'
'spam' * 3
# Out:
# 'spamspamspam'

# %% [raw]
# the value for the above two term will 'spamspamspam'

# %% [raw]
# (8) Why is eggs a valid variable name while 100 is invalid?

# %% [raw]
# because the variable name can not be a integer value.

# %% [raw]
# (9) What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [raw]
# int(), float(), str()

# %% [raw]
# (10) Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [raw]
# the expression cause error because we can not joint the integer and string value directly. for joining the integer and string value first have to convert the integer value to the string value then the join operation can be proceed.
#
# 'I have eaten ' + str(99) + ' burritos.'

# %%
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
