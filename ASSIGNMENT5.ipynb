# %% [raw]
# QUESTION 1. What does an empty dictionary's code look like?

# %% [raw]
# ANSWER 1. Empty dictionary's represented by two curly brackets.
# dic = {}

# %% [raw]
# QUESTION 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %% [raw]
# ANSWER 2. {'foo': 42}

# %% [raw]
# QUESTION 3. What is the most significant distinction between a dictionary and a list?

# %% [raw]
# ANSWER 3.
# The list is represented by the square baracket [] and dictionary is represented by the curly bracket{}.
# list is ordered and changeble and allows duplicate members but in dictionary is unordered and changeble and no duplicates member are allowed.
# the main difference is that the list items can accessed by their position but the dictionary can accessed by their key and values pair not by the position.

# %% [raw]
# QUESTION 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %% [raw]
# #ANSWER 4.
# spam = {'bar': 100}
# spam['foo']
#
# # it will show the KeyError: 'foo'

# %% [raw]
# QUESTION 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and
# 'cat' in spam.keys()?

# %% [raw]
# ANSWER 5.
# There is no differemce between the 'cat' in spam and 'cat' in spam.keys(). the both will check the key is present in the spam dictionary or not.

# %% [raw]
# QUESTION 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and
# 'cat' in spam.values()?

# %% [raw]
# ANSWER 6. 'cat' in spam will check is there any 'cat' key is availabe in spam dictionary and the 'cat' in spam.values() wil check is there any 'cat' value is available or not.

# %% [raw]
# QUESTION 7. What is a shortcut for the following code?
# if 'color' not in spam:
# spam['color'] = 'black'

# %% [raw]
# ANSWER 7.
# spam.setdefault('color','black')

# %% [raw]
# QUESTION 8. How do you "pretty print" dictionary values using which module and function?

# %%
#ANSWER 8.
#We can print the "pretty print" dictionary using the theree module which are as below
#(1) pprint module by using pprint fucntion 
#(2) json module by using dumps() function 
#(3) yaml module by using dumps() function 

dict1 = {"name":"rahul","position":"engineer","resident":{"country":"india","state":"gujarat"}}

#(1) pprint module by using pprint fucntion 
import pprint
print("print using the pprint module")
pprint.pprint(dict1)
print('-'*150)
         
#(2) json module by using dumps() function  
import json
val = json.dumps(dict1,indent = 1)
print("print using the json module:\n", val)   
print('-'*150)
         
#(3) yaml module by using dumps() function
import yaml
val1 = yaml.dump(dict1)
print("print using the ymal module:\n", val1)
# Out:
# print using the pprint module
# {'name': 'rahul',
#  'position': 'engineer',
#  'resident': {'country': 'india', 'state': 'gujarat'}}
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# print using the json module:
#  {
#  "name": "rahul",
#  "position": "engineer",
#  "resident": {
#   "country": "india",
#   "state": "gujarat"
#  }
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# print using the ymal module:
#  name: rahul
# position: engineer
# resident:
#   country: india
#   state: gujarat
